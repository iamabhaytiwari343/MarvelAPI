# %%
import pandas as pd

# %%
df=pd.read_csv("./marvel_characters.csv")

# %%
df.head(1)
# Out:
#         id     name description                  modified  \
# 0  1011334  3-D Man         NaN  2014-04-29T14:18:17-0400
#
#                                            thumbnail  \
# 0  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
#
#                                          resourceURI  \
# 0  http://gateway.marvel.com/v1/public/characters...
#
#                                               comics  \
# 0  {'available': 12, 'collectionURI': 'http://gat...
#
#                                               series  \
# 0  {'available': 3, 'collectionURI': 'http://gate...
#
#                                              stories  \
# 0  {'available': 21, 'collectionURI': 'http://gat...
#
#                                               events  \
# 0  {'available': 1, 'collectionURI': 'http://gate...
#
#                                                 urls
# 0  [{'type': 'detail', 'url': 'http://marvel.com/...

# %%
df.shape
# Out:
# (1562, 11)

# %%
# Search for a particular column
column_name = "name"
search_value = "Spider Man"
filtered_data = df[df[column_name] == search_value]

# Print the filtered data
print(filtered_data)
# Out:
# Empty DataFrame
# Columns: [id, name, description, modified, thumbnail, resourceURI, comics, series, stories, events, urls]
# Index: []

# %%
df
# Out:
#            id                        name  \
# 0     1011334                     3-D Man
# 1     1017100                A-Bomb (HAS)
# 2     1009144                      A.I.M.
# 3     1010699                 Aaron Stack
# 4     1009146  Abomination (Emil Blonsky)
# ...       ...                         ...
# 1557  1011515                        Zeus
# 1558  1011127                      Zodiak
# 1559  1009741        Zombie (Simon Garth)
# 1560  1011183                       Zuras
# 1561  1009742                       Zzzax
#
#                                             description  \
# 0                                                   NaN
# 1     Rick Jones has been Hulk's best bud since day ...
# 2     AIM is a terrorist organization bent on destro...
# 3                                                   NaN
# 4     Formerly known as Emil Blonsky, a spy of Sovie...
# ...                                                 ...
# 1557  Zeus ruled a peaceful Olympus for centuries wh...
# ...
